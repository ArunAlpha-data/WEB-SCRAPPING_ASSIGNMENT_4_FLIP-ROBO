# %% [markdown]
# # 5. To Scrape the details of trending repositories on Github.com.

# %%
# importing required libraries.
import pandas as pd
import selenium
import time

#importing Webdriver
from selenium import webdriver

#importing Exception Handling
from selenium.common.exceptions import NoSuchElementException

# %%
#connecting the web driver.
driver=webdriver.Chrome(r'C:\Program Files (x86)\chromedriver_win32\chromedriver.exe')

# %%
#connecting the website.
driver.get('https://github.com/')

# %%
#clicking the explore button
explore_button=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary")
explore_button.click()
time.sleep(2)

#clicking the trending button
trending_button=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a")
trending_button.click()

# %%
#creating empty list
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

# %%
#creating repository title list
repository=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/h1/a")
for i in repository:
    try:
        Repository_title.append(i.text)
    except:
        Repository_title.append("-")

# %%
#creating repository description list
repo_desc=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/p")
for i in repo_desc:
    try:
        Repository_description.append(i.text)
    except:
        Repository_description.appens("-")

# %%
#creating repository contributor list
contributor=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/div[2]/a[2]")
for i in contributor:
    try:
        Contributors_count.append(i.text)
    except:
        Contributors_count.append("-")

# %%
#creating repository language list
lang=driver.find_elements_by_xpath("//*[@id='js-pjax-container']/div[3]/div/div[2]/article/div[2]/span[1]/span[2]")
for i in lang:
    try:
        Language_used.append(i.text)
    except:
        Language_used.append("-")

# %%
#creating a data frame
Trending_repositories=pd.DataFrame([])
Trending_repositories["Repository_title"]=Repository_title[0:20]
Trending_repositories["Repository_description"]=Repository_description[0:20]
Trending_repositories["Contributors_count"]=Contributors_count[0:20]
Trending_repositories["Language_used"]=Language_used[0:20]

# %%
#data frame
Trending_repositories
# Out:
#                                      Repository_title  \
# 0   abuanwar072 / Flutter-Responsive-Admin-Panel-o...
# 1                     pallupz / covid-vaccine-booking
# 2                                   goharbor / harbor
# 3                           public-apis / public-apis
# 4               jwasham / coding-interview-university
# 5                          DIGITALCRIMINAL / OnlyFans
# 6                          facebookincubator / cinder
# 7                              vinta / awesome-python
# 8                     jlevy / the-art-of-command-line
# 9                                 dogecoin / dogecoin
# 10                            phamdinhkhanh / vnquant
# 11                                audacity / audacity
# 12                     Uniswap / uniswap-v3-periphery
# 13                      swar / Swar-Chia-Plot-Manager
# 14                                  flutter / flutter
# 15                              streamich / react-use
# 16                 dynamicwebpaige / thinking-in-data
# 17                                      forem / forem
# 18                                 Azure / counterfit
# 19                          Uniswap / uniswap-v3-core
#
#                                Repository_description Contributors_count  \
# 0   Responsive Admin Panel or Dashboard using Flutter                117
# 1   This very basic script can be used to automate...                 84
# 2   An open source trusted cloud native registry p...              3,683
# 3                      A collective list of free APIs             14,958
# 4   A complete computer science study plan to beco...             46,172
# 5   Scrape all the media from an OnlyFans account ...                222
# 6   Instagram's performance oriented fork of CPython.                 21
# 7   A curated list of awesome Python frameworks, l...             18,910
# 8                Master the command line, in one page              9,775
# 9                                       very currency              1,524
# 10                    VietNam Data Stock Market Price                 65
# 11                                       Audio Editor                959
# 12  🦄 🦄 🦄 Peripheral smart contracts for interacti...                 69
# 13  This is a Cross-Platform Plot Manager for Chia...                 31
# 14  Flutter makes it easy and fast to build beauti...             17,053
# 15                                    React Hooks — 👍              1,565
# 16  A VS Code extension pack to help users visuali...                 12
# 17                         For empowering community 🌱              2,846
# 18  a CLI that provides a generic automation layer...                 19
# 19           🦄 🦄 🦄 Core smart contracts of Uniswap v3                142
#
#    Language_used
# 0           Dart
# 1         Python
# 2             Go
# 3         Python
# 4         Python
# 5         Python
# 6         Python
# 7            C++
# 8           HTML
# 9              C
# 10    TypeScript
# 11        Python
# 12          Dart
# 13    TypeScript
# 14          Ruby
# 15        Python
# 16    TypeScript
# 17    TypeScript
# 18           PHP
# 19    TypeScript
